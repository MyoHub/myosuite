# %% [markdown]
# # MuscleMimic: mjlab GPU Backend
#
# Colab + CUDA: [11c_MuscleMimic_Fullbody_mjlab_colab.ipynb](./11c_MuscleMimic_Fullbody_mjlab_colab.ipynb).
#
# Demonstrates running the MuscleMimic fullbody task on the **mjlab** backend,
# which uses [Warp](https://github.com/NVIDIA/warp) for GPU-parallel simulation
# (falls back to CPU when CUDA is unavailable).
#
# Steps covered:
#
# 1. Verify mjlab / mujoco_warp / warp availability
# 2. Load a motion clip and register the mjlab task
# 3. Create a `ManagerBasedRlEnv` and run a zero-action rollout
# 4. Wrap with `RslRlVecEnvWrapper` and run PPO via `MjlabOnPolicyRunner`
# 5. Architecture summary

# %% [markdown]
# ## 0. Paths
#
# Automated runs (e.g. `jupyter nbconvert --execute`) may start the kernel with a working directory that is **not** inside this repo (often `/tmp`). In that case set **`MYOSUITE_REPO`** to the repository root (the directory that contains the `myosuite/` package). Optional smoke training length: **`MJLAB_MIMIC_DEMO_ITERS`** (defaults to `500`). Optional scale knobs: **`MJLAB_MIMIC_NUM_ENVS`** (defaults to `16`), **`MJLAB_MIMIC_STEPS_PER_ENV`** (defaults to `64`), **`MJLAB_MIMIC_RENDER_FRAMES`** (defaults to `300`), **`MJLAB_MIMIC_NCONMAX`**, and **`MJLAB_MIMIC_NJMAX`**. Optional logging backend: **`MJLAB_MIMIC_LOGGER`** (defaults to `tensorboard`; set to `wandb` only when authenticated).

# %%
import os
import sys
from pathlib import Path


def _find_myosuite_repo() -> Path:
    """Return repo root (directory that contains ``myosuite/``)."""
    env = os.environ.get('MYOSUITE_REPO', '').strip()
    if env:
        p = Path(env).expanduser().resolve()
        if (p / 'myosuite').is_dir():
            return p
    here = Path.cwd().resolve()
    for d in (here, *here.parents):
        if (d / 'myosuite').is_dir():
            return d
    raise RuntimeError(
        'Cannot find myosuite repo root. Run the notebook from inside the clone, '
        'or set MYOSUITE_REPO to the repository root (parent of the myosuite/ package).'
    )


_repo_root = _find_myosuite_repo()

if str(_repo_root) not in sys.path:
    sys.path.insert(0, str(_repo_root))
if str(_repo_root / 'tutorials') not in sys.path:
    sys.path.insert(0, str(_repo_root / 'tutorials'))

print('Repo root:', _repo_root)
# Out:
# Repo root: C:\Users\florian\myosuite

# %% [markdown]
# ## 1. Verify mjlab / mujoco_warp / warp / musclemimic
#
# `mjlab` requires:
# - `warp-lang` — GPU kernel framework (CPU fallback when no CUDA)
# - `mujoco_warp` — MuJoCo physics compiled to Warp kernels
# - `mjlab` — task / env / runner framework built on the above
# - `musclemimic` + dependencies — MuscleMimic package (easiest to install via myosuite[musclemimic])
#
# If missing, run the following two lines, where "cu130" should be replaced by the CUDA version supported by your system (the latest version can be found by running `nvidia-smi` in the terminal), e.g., cu126 for CUDA 12.6:
# ```bash
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130 --force-reinstall
# pip install myosuite[warp] myosuite[musclemimic]
# ```

# %%
import warnings
warnings.filterwarnings('ignore')

_MJLAB_OK = False
_MJLAB_RUN = False
_DEVICE = 'cpu'
CLIP_PATH = None

try:
    import warp as wp
    import mujoco_warp
    import mjlab
    import platform
    devices = wp.get_devices()
    _DEVICE = 'cuda' if any(d.is_cuda for d in devices) else 'cpu'
    _MJLAB_OK = True
    _MJLAB_RUN = _DEVICE == 'cuda' and platform.system() != 'Darwin'
    # Register MyoSuite task ids with mjlab (entry point is not always run on ``import mjlab``).
    try:
        import importlib
        importlib.import_module('myosuite.envs.myo.backends.mjlab')
    except ImportError:
        pass
    print(f'warp {wp.__version__}  |  mujoco_warp {mujoco_warp.__version__}  |  mjlab OK')
    print(f'Warp devices: {[str(d) for d in devices]}')
    print(f'Using device: {_DEVICE}')
    if not _MJLAB_RUN:
        print('[SKIP] mjlab env/rollout cells need Linux + CUDA (Warp can hang on CPU/macOS).')
except ImportError as e:
    print(f'[SKIP] mjlab not available: {e}')
    print('Install with: pip install myosuite[mjlab] myosuite[musclemimic]')
# Out:
# Warp 1.17.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.1
#    Devices:
#      "cpu"      : "Intel64 Family 6 Model 167 Stepping 1, GenuineIntel"
#      "cuda:0"   : "NVIDIA GeForce GTX 1660 SUPER" (6 GiB, sm_75, mempool enabled)
#    Kernel cache:
#      \\?\C:\Users\florian\AppData\Local\NVIDIA\warp\Cache\1.17.0
# warp 1.17.0  |  mujoco_warp 3.11.0  |  mjlab OK
# Warp devices: ['cpu', 'cuda:0']
# Using device: cuda

# %% [markdown]
# ## 2. Load the motion clip
#
# The mjlab mimic task requires a retargeted `.npz` clip with
# `xpos`, `xquat`, `qpos`, `qvel`, and `site_xpos` arrays.
# Use `hf_hub_download(...)` to resolve the local file path in a machine-agnostic way:
#
# ```python
# from pathlib import Path
# from huggingface_hub import hf_hub_download
#
# CLIP_REPO_ID = 'amathislab/musclemimic-retargeted'
# CLIP_FILENAME = 'MyoFullBody/gmr/KIT/167/walking_medium06_poses.npz'
#
# CLIP_PATH = Path(
#     hf_hub_download(
#         repo_id=CLIP_REPO_ID,
#         filename=CLIP_FILENAME,
#         repo_type='dataset',
#     )
# )
# ```
#
# **NOTE:** You may need to first go to https://huggingface.co/datasets/amathislab/musclemimic-retargeted and accept the licence requirements for this dataset; afterwards, create an huggingface access token and paste it into the next cell:

# %%
import os
os.environ["HF_TOKEN"] = ""  #access token from your huggingface account goes here

# %%
from pathlib import Path
from huggingface_hub import hf_hub_download

CLIP_REPO_ID = 'amathislab/musclemimic-retargeted'
CLIP_FILENAME = 'MyoFullBody/gmr/KIT/167/walking_medium06_poses.npz'
CLIP_PATH = None
try:
    CLIP_PATH = Path(
        hf_hub_download(
            repo_id=CLIP_REPO_ID,
            filename=CLIP_FILENAME,
            repo_type='dataset',
        )
    )
    if not CLIP_PATH.is_file():
        raise FileNotFoundError(CLIP_PATH)
    print('Clip:', CLIP_PATH)
except Exception as e:
    CLIP_PATH = None
    print(f'[SKIP] Full-body clip not downloaded ({type(e).__name__}: {e})')
    print('Need network access to huggingface.co/datasets/amathislab/musclemimic-retargeted')
# Out:
# Clip: C:\Users\florian\.cache\huggingface\hub\datasets--amathislab--musclemimic-retargeted\snapshots\0c1c8f9ead144b2d783e900f8fb640d2f7a815ce\MyoFullBody\gmr\KIT\167\walking_medium06_poses.npz

# %%
from pathlib import Path
from huggingface_hub import hf_hub_download

BIMANUAL_CLIP_PATH = None
try:
    BIMANUAL_CLIP_PATH = Path(
        hf_hub_download(
            repo_id='amathislab/musclemimic-bimanual-retargeted',
            filename='MyoBimanualArm/gmr/BioMotionLab_NTroje/rub001/0011_lifting_light1_poses.npz',
            repo_type='dataset',
        )
    )
    print('Optional bimanual clip:', BIMANUAL_CLIP_PATH)
except Exception as e:
    print(
        '[SKIP] Bimanual clips are on a gated Hugging Face dataset '
        f'({type(e).__name__}). Request access at '
        'https://huggingface.co/datasets/amathislab/musclemimic-bimanual-retargeted'
    )
    print('The full-body CLIP_PATH from the previous cell is unchanged.')
# Out:
# Optional bimanual clip: C:\Users\florian\.cache\huggingface\hub\datasets--amathislab--musclemimic-bimanual-retargeted\snapshots\54f108ad04de069dfdbc4363eb6ad5bb7e8778bc\MyoBimanualArm\gmr\BioMotionLab_NTroje\rub001\0011_lifting_light1_poses.npz

# %% [markdown]
# ## 3. Load MotionClip and register task
#
# `load_motion_clip` validates array shapes and populates a typed
# `MotionClip` dataclass.  `register_mimic_mjlab_tasks_with_clip` creates
# a `ManagerBasedRlEnvCfg` for `myoMimicFullbody-v0` using this clip as the
# trajectory target source.

# %%
if _MJLAB_OK and _MJLAB_RUN and CLIP_PATH:
    import numpy as np
    from mjlab.tasks.registry import register_mjlab_task
    from myosuite.core.trajectory_io import load_motion_clip
    from myosuite.envs.myo.backends.mjlab.mimic_mjlab_env import (
        default_mimic_clip_on_policy_runner_cfg,
        register_mimic_mjlab_tasks_with_clip,
    )

    clip = load_motion_clip(CLIP_PATH, expected_nq=89, expected_nv=88)
    print(f'Clip loaded: T={clip.qpos.shape[0]} frames  nq={clip.qpos.shape[1]}')

    register_mimic_mjlab_tasks_with_clip(
        register_mjlab_task=register_mjlab_task,
        rl_cfg_fn=default_mimic_clip_on_policy_runner_cfg,
        clip=clip,
        use_lookahead=True,
    )
    print('Registered: myoMimicFullbody-v0')
# Out:
# Clip loaded: T=484 frames  nq=89
# Registered: myoMimicFullbody-v0

# %% [markdown]
# ## 4. Create `ManagerBasedRlEnv` and run a rollout
#
# Instantiate the mjlab env with 2 parallel environments and step it
# for 10 steps with zero actions to verify physics runs correctly.
#
# The cell registers `myoMimicFullbody-v0` if it is not already in the
# registry (e.g. after a kernel restart or when running cells out of order),
# then calls `load_env_cfg` to retrieve the config.

# %%
if _MJLAB_OK and _MJLAB_RUN and CLIP_PATH:
    import torch
    from mjlab.tasks.registry import list_tasks, load_env_cfg, register_mjlab_task
    from mjlab.envs import ManagerBasedRlEnv

    # Register the task if cell 8 was skipped (e.g. kernel restart in Colab).
    if 'myoMimicFullbody-v0' not in list_tasks():
        from myosuite.core.trajectory_io import load_motion_clip
        from myosuite.envs.myo.backends.mjlab.mimic_mjlab_env import (
            default_mimic_clip_on_policy_runner_cfg,
            register_mimic_mjlab_tasks_with_clip,
        )
        _clip = load_motion_clip(CLIP_PATH, expected_nq=89, expected_nv=88)
        register_mimic_mjlab_tasks_with_clip(
            register_mjlab_task=register_mjlab_task,
            rl_cfg_fn=default_mimic_clip_on_policy_runner_cfg,
            clip=_clip,
            use_lookahead=True,
        )
        print('Registered: myoMimicFullbody-v0')

    NUM_ENVS = int(os.environ.get('MJLAB_MIMIC_NUM_ENVS', '16'))  # increase to 512-2048 on GPU
    env_cfg = load_env_cfg('myoMimicFullbody-v0')
    env_cfg.scene.num_envs = NUM_ENVS
    if os.environ.get('MJLAB_MIMIC_NCONMAX'):
        env_cfg.sim.nconmax = int(os.environ['MJLAB_MIMIC_NCONMAX'])
    if os.environ.get('MJLAB_MIMIC_NJMAX'):
        env_cfg.sim.njmax = int(os.environ['MJLAB_MIMIC_NJMAX'])

    train_env = ManagerBasedRlEnv(cfg=env_cfg, device=_DEVICE)
    obs, _ = train_env.reset()
    act_dim = train_env.action_space.shape[-1]
    obs_dim = obs['actor'].shape[-1]
    print(f'obs_dim={obs_dim}  act_dim={act_dim}  num_envs={NUM_ENVS}')

    for step in range(10):
        actions = torch.zeros(NUM_ENVS, act_dim, device=_DEVICE)
        obs, rew, term, trunc, info = train_env.step(actions)

    print(f'Rollout OK — obs[actor] shape: {obs["actor"].shape}')
# Out:
# Module mujoco_warp._src.smooth b9cc505 load on device 'cuda:0' took 9672.03 ms  (compiled)
# Module _nxn_broadphase__locals__kernel_3a0c7ab9 3a0c7ab load on device 'cuda:0' took 753.46 ms  (compiled)
# Module ccd_kernel_builder__locals__ccd_kernel_e842fbdb e842fbd load on device 'cuda:0' took 15598.09 ms  (compiled)
# Module ccd_kernel_builder__locals__ccd_kernel_e842fbdb 2108b59 load on device 'cuda:0' took 15665.02 ms  (compiled)
# Module ccd_kernel_builder__locals__ccd_kernel_268ca22c 268ca22 load on device 'cuda:0' took 14474.62 ms  (compiled)
# Module ccd_kernel_builder__locals__ccd_kernel_268ca22c 7f933b9 load on device 'cuda:0' took 14470.94 ms  (compiled)
# Module _primitive_narrowphase__locals__primitive_narrowphase_4770cfa2 4770cfa load on device 'cuda:0' took 1339.40 ms  (compiled)
# Module mujoco_warp._src.constraint 9435a53 load on device 'cuda:0' took 210.73 ms  (compiled)
# Module _equality_joint__locals__kernel_993e5691 993e569 load on device 'cuda:0' took 440.02 ms  (compiled)
# Module _friction_dof__locals__kernel_85239eb5 85239eb load on device 'cuda:0' took 390.27 ms  (compiled)
# Module _friction_tendon__locals__kernel_9fdcef5b 9fdcef5 load on device 'cuda:0' took 433.64 ms  (compiled)
# Module _limit_slide_hinge__locals__kernel_b8014c9f b8014c9 load on device 'cuda:0' took 408.59 ms  (compiled)
# Module _efc_contact_init__locals__kernel_34eca94d 34eca94 load on device 'cuda:0' took 319.28 ms  (compiled)
# Module _efc_contact_jac_sparse__locals__kernel_eb752226 eb75222 load on device 'cuda:0' took 391.75 ms  (compiled)
# Module _efc_contact_update__locals__kernel_1a7e7f98 1a7e7f9 load on device 'cuda:0' took 379.71 ms  (compiled)
# Module mujoco_warp._src.forward f44d3e1 load on device 'cuda:0' took 2162.44 ms  (compiled)
# Module mujoco_warp._src.forward 0a75030 load on device 'cuda:0' took 1788.75 ms  (compiled)
# Module mujoco_warp._src.passive 80f3681 load on device 'cuda:0' took 3263.18 ms  (compiled)
# Module mujoco_warp._src.sensor 764597f load on device 'cuda:0' took 6481.87 ms  (compiled)
# Module _qfrc_smooth__locals__kernel_2c4e0694 2c4e069 load on device 'cuda:0' took 188.90 ms  (compiled)
# Module mujoco_warp._src.support f39c2de load on device 'cuda:0' took 360.00 ms  (compiled)
# Module _solve_LD_sparse_fused__locals__kernel_49706fc5 4966dd7 load on device 'cuda:0' took 641.16 ms  (compiled)
# Module _solve_init_dof__locals__kernel_48710307 4871030 load on device 'cuda:0' took 190.46 ms  (compiled)
# Module mujoco_warp._src.solver c97221b load on device 'cuda:0' took 2079.97 ms  (compiled)
# Module _solve_init_jaref_kernel__locals__kernel_ec73559d ec73559 load on device 'cuda:0' took 260.64 ms  (compiled)
# Module mul_m_kernel__locals___mul_m_74986a16 74986a1 load on device 'cuda:0' took 248.70 ms  (compiled)
# Module _update_constraint_efc__locals__kernel_ed085732 ed08573 load on device 'cuda:0' took 277.89 ms  (compiled)
# Module _update_constraint_init_qfrc_constraint_sparse__locals__kernel_67d0743a 67d0743 load on device 'cuda:0' took 255.41 ms  (compiled)
# Module _update_gradient_zero_grad_dot__locals__kernel_ada3cc5f ada3cc5 load on device 'cuda:0' took 194.63 ms  (compiled)
# Module _update_gradient_grad__locals__kernel_45d59ec9 45d59ec load on device 'cuda:0' took 192.34 ms  (compiled)
# Module _update_gradient_init_h_sparse__locals__kernel_3d60cf50 3d60cf5 load on device 'cuda:0' took 214.54 ms  (compiled)
# Module _JTDAJ_sparse__locals__kernel_eac33f90 eac33f9 load on device 'cuda:0' took 275.14 ms  (compiled)
# Module _JTDAJ_sparse__locals__kernel_eac33f90 afcc61a load on device 'cuda:0' took 272.80 ms  (compiled)
# Module _update_gradient_cholesky_blocked__locals__kernel_0de4757d 5477a30 load on device 'cuda:0' took 7806.61 ms  (compiled)
# Module _linesearch_jv_fused_kernel__locals__kernel_071c2705 071c270 load on device 'cuda:0' took 267.66 ms  (compiled)
# Module _linesearch_iterative_kernel__locals__kernel_5bd15791 989f9df load on device 'cuda:0' took 824.71 ms  (compiled)
# Module _update_constraint_efc__locals__kernel_b09277e7 b09277e load on device 'cuda:0' took 312.75 ms  (compiled)
# Module _update_gradient_zero_grad_dot__locals__kernel_90b73b32 90b73b3 load on device 'cuda:0' took 224.85 ms  (compiled)
# Module _update_gradient_grad__locals__kernel_89d63404 89d6340 load on device 'cuda:0' took 208.78 ms  (compiled)
# Module _update_gradient_h_incremental_sparse__locals__kernel_8510a60f 8510a60 load on device 'cuda:0' took 280.80 ms  (compiled)
# Module _update_gradient_cholesky_blocked_skip_unchanged__locals__kernel_300a5d11 6848739 load on device 'cuda:0' took 6086.38 ms  (compiled)
# Module mujoco_warp._src.derivative 1d93a53 load on device 'cuda:0' took 1927.09 ms  (compiled)
# Module _next_time_builder__locals___next_time_cc50a46c cc50a46 load on device 'cuda:0' took 217.14 ms  (compiled)
# Module reset_data__locals__reset_xfrc_applied_c7eeecfb c7eeecf load on device 'cuda:0' took 184.89 ms  (compiled)
# Module reset_data__locals__reset_M_d1ea7a8e d1ea7a8 load on device 'cuda:0' took 180.09 ms  (compiled)
# Module reset_data__locals__reset_mocap_b017f38a b017f38 load on device 'cuda:0' took 221.31 ms  (compiled)
# Module reset_data__locals__reset_contact_757d9bde 757d9bd load on device 'cuda:0' took 237.17 ms  (compiled)
# Module reset_data__locals__reset_sleep_6b3be194 6b3be19 load on device 'cuda:0' took 217.06 ms  (compiled)
# Module reset_data__locals__reset_nworld_e471a890 e471a89 load on device 'cuda:0' took 306.25 ms  (compiled)
#
# +--------------------------------+
# |        Base Environment        |
# +------------------------+-------+
# | Property               | Value |
# +------------------------+-------+
# | Number of environments | 16    |
# | Environment device     | cuda  |
# | Environment seed       | None  |
# | Physics step-size      | 0.002 |
# | Environment step-size  | 0.01  |
# +------------------------+-------+
#
# [INFO] <EventManager> contains 1 active terms.
# +-------------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +-------------------+-----------------+
# |       Index       | Name            |
# +-------------------+-----------------+
# |         0         | rsi             |
# +-------------------+-----------------+
#
# [INFO] <NullCommandManager> (inactive)
# [INFO] <ActionManager> contains 1 active terms.
# +----------------------------------+
# | Active Action Terms (shape: 354) |
# +--------+----------+--------------+
# | Index  | Name     |    Dimension |
# +--------+----------+--------------+
# |   0    | muscles  |          354 |
# +--------+----------+--------------+
#
# [INFO] <ObservationManager> contains 3 groups.
# +--------------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (1152,)) |
# +-----------+----------------------------------+---------------+
# |   Index   | Name                             |     Shape     |
# +-----------+----------------------------------+---------------+
# |     0     | qpos                             |     (89,)     |
# |     1     | qvel                             |     (88,)     |
# |     2     | act                              |     (354,)    |
# |     3     | mimic_site_pos                   |     (51,)     |
# |     4     | mimic_site_target                |     (51,)     |
# |     5     | mimic_site_err                   |     (51,)     |
# |     6     | clip_ref_qpos                    |     (89,)     |
# |     7     | clip_ref_qvel                    |     (88,)     |
# |     8     | clip_phase                       |      (1,)     |
# |     9     | mimic_lookahead                  |     (290,)    |
# +-----------+----------------------------------+---------------+
# +-------------------------------------------------------------+
# | Active Observation Terms in Group: 'actor' (shape: (1152,)) |
# +-----------+----------------------------------+--------------+
# |   Index   | Name                             |    Shape     |
# +-----------+----------------------------------+--------------+
# |     0     | qpos                             |    (89,)     |
# |     1     | qvel                             |    (88,)     |
# |     2     | act                              |    (354,)    |
# |     3     | mimic_site_pos                   |    (51,)     |
# |     4     | mimic_site_target                |    (51,)     |
# |     5     | mimic_site_err                   |    (51,)     |
# |     6     | clip_ref_qpos                    |    (89,)     |
# |     7     | clip_ref_qvel                    |    (88,)     |
# |     8     | clip_phase                       |     (1,)     |
# |     9     | mimic_lookahead                  |    (290,)    |
# +-----------+----------------------------------+--------------+
# +--------------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (1152,)) |
# +-----------+----------------------------------+---------------+
# |   Index   | Name                             |     Shape     |
# +-----------+----------------------------------+---------------+
# |     0     | qpos                             |     (89,)     |
# |     1     | qvel                             |     (88,)     |
# |     2     | act                              |     (354,)    |
# |     3     | mimic_site_pos                   |     (51,)     |
# |     4     | mimic_site_target                |     (51,)     |
# |     5     | mimic_site_err                   |     (51,)     |
# |     6     | clip_ref_qpos                    |     (89,)     |
# |     7     | clip_ref_qvel                    |     (88,)     |
# |     8     | clip_phase                       |      (1,)     |
# |     9     | mimic_lookahead                  |     (290,)    |
# +-----------+----------------------------------+---------------+
#
# [INFO] <TerminationManager> contains 2 active terms.
# +------------------------------------+
# |      Active Termination Terms      |
# +-------+-----------------+----------+
# | Index | Name            | Time Out |
# +-------+-----------------+----------+
# |   0   | time_out        |   True   |
# |   1   | mimic_deviation |  False   |
# +-------+-----------------+----------+
#
# [INFO] <RewardManager> contains 1 active terms.
# +---------------------------+
# |    Active Reward Terms    |
# +-------+----------+--------+
# | Index | Name     | Weight |
# +-------+----------+--------+
# |   0   | tracking |  500.0 |
# +-------+----------+--------+
#
# [INFO] <NullCurriculumManager> (inactive)
# [INFO] <NullMetricsManager> (inactive)
# [INFO] <NullRecorderManager> (inactive)
# obs_dim=1152  act_dim=354  num_envs=16
# Rollout OK — obs[actor] shape: torch.Size([16, 1152])

# %% [markdown]
# ## 5. PPO training with `MjlabOnPolicyRunner`
#
# `RslRlVecEnvWrapper` adapts the `ManagerBasedRlEnv` to the `rsl_rl` API.
# `MjlabOnPolicyRunner` runs the PPO update loop.
#
# **Why raw `RslRlOnPolicyRunnerCfg()` can plateau (e.g. mean return ~10–15)** while
# `tutorials/mimic/train_mimic.py` on the same clip keeps improving:
#
# | Aspect | `train_mimic` + `MuscleMimicClipEnvV0` | mjlab default runner cfg |
# |--------|----------------------------------------|---------------------------|
# | Observations | `RunningMeanStd` when `use_obs_normalizer=True` (default) | `obs_normalization=False` on actor/critic |
# | MLP | 256-wide × 4 layers, SiLU + LayerNorm | 128³, ELU |
# | LR / entropy | 3e-4, entropy 1e-3 | 1e-3, 5e-3 |
# | LR schedule | Linear anneal | `adaptive` + `desired_kl` (can shrink LR early) |
# | Actions | Direct muscle `ctrl` in `[0, 1]` (Gaussian + clip) | `[-1,1]` → `sigmoid(5*(a-0.5))` into muscles |
#
# The registration cell above uses ``default_mimic_clip_on_policy_runner_cfg`` from
# ``mimic_mjlab_env`` so the task’s stored RL config matches that regime.  The
# training cell builds the runner from the same helper and calls
# ``install_episode_reward_logging_patch()`` so **mean episode return** in logs
# matches rsl_rl’s internal buffers (upstream rsl_rl only fills ``rewbuffer``
# when a SummaryWriter exists).
#
# You still need **many more steps** than the CPU demo for gym-class convergence
# (order 10⁷–10⁹ env steps).  Optional: ``python scripts/bench_mjlab_mimic_ppo.py``
# compares baseline vs tuned configs headlessly.
#
# **Hardware** (adjust to your machine):
#
# | Setting | CPU (demo) | GPU (training) |
# |---------|-----------|----------------|
# | `NUM_ENVS` | 16 | 512–2048 |
# | `num_steps_per_env` | 64 | 128 |
# | `max_iterations` | 500 | 5 000+ |
#
# On CPU, 500 × 16 × 64 ≈ **512 k** env steps — a smoke test only.

# %%
if _MJLAB_OK and _MJLAB_RUN and CLIP_PATH:
    import dataclasses
    import os
    import torch
    from mjlab.rl import RslRlVecEnvWrapper, MjlabOnPolicyRunner

    from myosuite.envs.myo.backends.mjlab.mimic_mjlab_env import (
        default_mimic_clip_on_policy_runner_cfg,
    )
    from myosuite.envs.myo.backends.mjlab.rsl_rl_logger_episode_patch import (
        install_episode_reward_logging_patch,
    )

    TRAIN_LOG_DIR = '/tmp/mjlab_mimic'
    # Override for CI / nbconvert smoke: ``MJLAB_MIMIC_DEMO_ITERS=2 jupyter nbconvert ...``
    NUM_ITERS = int(os.environ.get('MJLAB_MIMIC_DEMO_ITERS', '500'))
    STEPS_PER_ENV = int(os.environ.get('MJLAB_MIMIC_STEPS_PER_ENV', '64'))

    wrapped = RslRlVecEnvWrapper(train_env)

    # Same defaults as registration (default_mimic_clip_on_policy_runner_cfg).
    runner_cfg = dataclasses.asdict(default_mimic_clip_on_policy_runner_cfg())
    runner_cfg['logger'] = os.environ.get('MJLAB_MIMIC_LOGGER', 'tensorboard')
    runner_cfg['num_steps_per_env'] = STEPS_PER_ENV
    runner_cfg['max_iterations'] = NUM_ITERS
    # Save at least once before the final iter so short smoke runs still get a ckpt.
    runner_cfg['save_interval'] = min(100, max(1, NUM_ITERS))

    install_episode_reward_logging_patch()

    runner = MjlabOnPolicyRunner(
        env=wrapped,
        train_cfg=runner_cfg,
        log_dir=TRAIN_LOG_DIR,
        device=_DEVICE,
    )
    runner.learn(num_learning_iterations=NUM_ITERS, init_at_random_ep_len=True)
    print(f'Training complete — checkpoints in {TRAIN_LOG_DIR}')
# Out:
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 actor :  ('actor',)
# 	 critic :  ('critic',)
# --------------------------------------------------------------------------------
# Actor Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (distribution): GaussianDistribution()
#   (mlp): MLP(
#     (0): Linear(in_features=1152, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=354, bias=True)
#   )
# )
# Critic Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (mlp): MLP(
#     (0): Linear(in_features=1152, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#   )
# )
# Storing git diff for 'myosuite' in: /tmp/mjlab_mimic\git\myosuite.diff
# ################################################################################
#                             Learning iteration 0/500
#
#                             Total steps: 1024
#                        Steps per second: 243
#                         Collection time: 3.839s
#                           Learning time: 0.373s
#                         Mean value loss: 287.7828
#                     Mean surrogate loss: 0.0122
#                       Mean entropy loss: 502.3172
#                             Mean reward: 65.37
#                     Mean episode length: 41.00
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1333
#                 Episode_Reward/tracking: 6.5805
#            Episode_Termination/time_out: 0.0667
# --------------------------------------------------------------------------------
#                          Iteration time: 4.21s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:35:01
#
# ################################################################################
#                             Learning iteration 1/500
#
#                             Total steps: 2048
#                        Steps per second: 262
#                         Collection time: 3.730s
#                           Learning time: 0.167s
#                         Mean value loss: 226.6038
#                     Mean surrogate loss: -0.0584
#                       Mean entropy loss: 502.3397
#                             Mean reward: 71.14
#                     Mean episode length: 43.41
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0000
#                 Episode_Reward/tracking: 7.6606
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.90s
#                            Time elapsed: 0:00:08
#                                     ETA: 0:33:38
#
# ################################################################################
#                             Learning iteration 2/500
#
#                             Total steps: 3072
#                        Steps per second: 288
#                         Collection time: 3.407s
#                           Learning time: 0.147s
#                         Mean value loss: 210.5347
#                     Mean surrogate loss: -0.0819
#                       Mean entropy loss: 502.3754
#                             Mean reward: 70.91
#                     Mean episode length: 43.95
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.3750
#                 Episode_Reward/tracking: 7.0813
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.55s
#                            Time elapsed: 0:00:11
#                                     ETA: 0:32:12
#
# ################################################################################
#                             Learning iteration 3/500
#
#                             Total steps: 4096
#                        Steps per second: 285
#                         Collection time: 3.444s
#                           Learning time: 0.148s
#                         Mean value loss: 225.1702
#                     Mean surrogate loss: -0.0800
#                       Mean entropy loss: 502.4178
#                             Mean reward: 72.12
#                     Mean episode length: 45.77
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1500
#                 Episode_Reward/tracking: 7.5520
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.59s
#                            Time elapsed: 0:00:15
#                                     ETA: 0:31:31
#
# ################################################################################
#                             Learning iteration 4/500
#
#                             Total steps: 5120
#                        Steps per second: 287
#                         Collection time: 3.405s
#                           Learning time: 0.161s
#                         Mean value loss: 220.3523
#                     Mean surrogate loss: -0.0782
#                       Mean entropy loss: 502.4696
#                             Mean reward: 73.06
#                     Mean episode length: 46.27
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2222
#                 Episode_Reward/tracking: 7.2364
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.57s
#                            Time elapsed: 0:00:18
#                                     ETA: 0:31:03
#
# ################################################################################
#                             Learning iteration 5/500
#
#                             Total steps: 6144
#                        Steps per second: 286
#                         Collection time: 3.423s
#                           Learning time: 0.153s
#                         Mean value loss: 216.0700
#                     Mean surrogate loss: -0.0764
#                       Mean entropy loss: 502.5241
#                             Mean reward: 73.28
#                     Mean episode length: 47.03
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0000
#                 Episode_Reward/tracking: 7.2877
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.58s
#                            Time elapsed: 0:00:22
#                                     ETA: 0:30:44
#
# ################################################################################
#                             Learning iteration 6/500
#
#                             Total steps: 7168
#                        Steps per second: 285
#                         Collection time: 3.425s
#                           Learning time: 0.167s
#                         Mean value loss: 193.2770
#                     Mean surrogate loss: -0.0803
#                       Mean entropy loss: 502.5770
#                             Mean reward: 72.27
#                     Mean episode length: 46.76
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1667
#                 Episode_Reward/tracking: 6.9342
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.59s
#                            Time elapsed: 0:00:25
#                                     ETA: 0:30:30
#
# ################################################################################
#                             Learning iteration 7/500
#
#                             Total steps: 8192
#                        Steps per second: 282
#                         Collection time: 3.431s
#                           Learning time: 0.197s
#                         Mean value loss: 182.1423
#                     Mean surrogate loss: -0.0796
#                       Mean entropy loss: 502.6327
#                             Mean reward: 72.45
#                     Mean episode length: 47.32
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1579
#                 Episode_Reward/tracking: 7.4206
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.63s
#                            Time elapsed: 0:00:29
#                                     ETA: 0:30:21
#
# ################################################################################
#                             Learning iteration 8/500
#
#                             Total steps: 9216
#                        Steps per second: 260
#                         Collection time: 3.746s
#                           Learning time: 0.190s
#                         Mean value loss: 212.1908
#                     Mean surrogate loss: -0.0788
#                       Mean entropy loss: 502.6819
#                             Mean reward: 72.40
#                     Mean episode length: 47.62
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1579
#                 Episode_Reward/tracking: 7.1484
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.94s
#                            Time elapsed: 0:00:33
#                                     ETA: 0:30:30
#
# ################################################################################
#                             Learning iteration 9/500
#
#                             Total steps: 10240
#                        Steps per second: 232
#                         Collection time: 4.069s
#                           Learning time: 0.335s
#                         Mean value loss: 212.6012
#                     Mean surrogate loss: -0.0818
#                       Mean entropy loss: 502.7300
#                             Mean reward: 73.49
#                     Mean episode length: 48.62
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1000
#                 Episode_Reward/tracking: 7.5559
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 4.40s
#                            Time elapsed: 0:00:37
#                                     ETA: 0:30:59
#
# ################################################################################
#                            Learning iteration 10/500
#
#                             Total steps: 11264
#                        Steps per second: 234
#                         Collection time: 4.145s
#                           Learning time: 0.221s
#                         Mean value loss: 208.2398
#                     Mean surrogate loss: -0.0816
#                       Mean entropy loss: 502.7836
#                             Mean reward: 72.54
#                     Mean episode length: 47.07
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.3750
#                 Episode_Reward/tracking: 7.4309
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 4.37s
#                            Time elapsed: 0:00:42
#                                     ETA: 0:31:21
#
# ################################################################################
#                            Learning iteration 11/500
#
#                             Total steps: 12288
#                        Steps per second: 239
#                         Collection time: 4.064s
#                           Learning time: 0.214s
#                         Mean value loss: 179.3649
#                     Mean surrogate loss: -0.0793
#                       Mean entropy loss: 502.8452
#                             Mean reward: 74.25
#                     Mean episode length: 48.11
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2500
#                 Episode_Reward/tracking: 7.2735
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 4.28s
#                            Time elapsed: 0:00:46
#                                     ETA: 0:31:35
#
# ################################################################################
#                            Learning iteration 12/500
#
#                             Total steps: 13312
#                        Steps per second: 253
#                         Collection time: 3.859s
#                           Learning time: 0.173s
#                         Mean value loss: 174.3248
#                     Mean surrogate loss: -0.0805
#                       Mean entropy loss: 502.9094
#                             Mean reward: 74.45
#                     Mean episode length: 47.41
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2222
#                 Episode_Reward/tracking: 7.2520
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 4.03s
#                            Time elapsed: 0:00:50
#                                     ETA: 0:31:36
#
# ################################################################################
#                            Learning iteration 13/500
#
#                             Total steps: 14336
#                        Steps per second: 268
#                         Collection time: 3.630s
#                           Learning time: 0.181s
#                         Mean value loss: 154.5574
#                     Mean surrogate loss: -0.0793
#                       Mean entropy loss: 502.9649
#                             Mean reward: 72.77
#                     Mean episode length: 46.87
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2000
#                 Episode_Reward/tracking: 6.8653
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.81s
#                            Time elapsed: 0:00:54
#                                     ETA: 0:31:29
#
# ################################################################################
#                            Learning iteration 14/500
#
#                             Total steps: 15360
#                        Steps per second: 270
#                         Collection time: 3.604s
#                           Learning time: 0.176s
#                         Mean value loss: 154.7662
#                     Mean surrogate loss: -0.0825
#                       Mean entropy loss: 503.0228
#                             Mean reward: 71.73
#                     Mean episode length: 45.91
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.3125
#                 Episode_Reward/tracking: 7.3844
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.78s
#                            Time elapsed: 0:00:58
#                                     ETA: 0:31:22
#
# ################################################################################
#                            Learning iteration 15/500
#
#                             Total steps: 16384
#                        Steps per second: 285
#                         Collection time: 3.432s
#                           Learning time: 0.155s
#                         Mean value loss: 132.3400
#                     Mean surrogate loss: -0.0803
#                       Mean entropy loss: 503.0844
#                             Mean reward: 70.96
#                     Mean episode length: 46.54
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0952
#                 Episode_Reward/tracking: 6.9812
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.59s
#                            Time elapsed: 0:01:01
#                                     ETA: 0:31:09
#
# ################################################################################
#                            Learning iteration 16/500
#
#                             Total steps: 17408
#                        Steps per second: 288
#                         Collection time: 3.387s
#                           Learning time: 0.159s
#                         Mean value loss: 134.7324
#                     Mean surrogate loss: -0.0803
#                       Mean entropy loss: 503.1442
#                             Mean reward: 70.05
#                     Mean episode length: 46.07
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1765
#                 Episode_Reward/tracking: 7.0930
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.55s
#                            Time elapsed: 0:01:05
#                                     ETA: 0:30:56
#
# ################################################################################
#                            Learning iteration 17/500
#
#                             Total steps: 18432
#                        Steps per second: 286
#                         Collection time: 3.415s
#                           Learning time: 0.158s
#                         Mean value loss: 151.6803
#                     Mean surrogate loss: -0.0804
#                       Mean entropy loss: 503.2009
#                             Mean reward: 70.80
#                     Mean episode length: 46.71
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0909
#                 Episode_Reward/tracking: 7.5090
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.57s
#                            Time elapsed: 0:01:08
#                                     ETA: 0:30:45
#
# ################################################################################
#                            Learning iteration 18/500
#
#                             Total steps: 19456
#                        Steps per second: 276
#                         Collection time: 3.537s
#                           Learning time: 0.165s
#                         Mean value loss: 133.5348
#                     Mean surrogate loss: -0.0785
#                       Mean entropy loss: 503.2515
#                             Mean reward: 70.99
#                     Mean episode length: 45.88
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1818
#                 Episode_Reward/tracking: 6.9430
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.70s
#                            Time elapsed: 0:01:12
#                                     ETA: 0:30:38
#
# ################################################################################
#                            Learning iteration 19/500
#
#                             Total steps: 20480
#                        Steps per second: 275
#                         Collection time: 3.538s
#                           Learning time: 0.175s
#                         Mean value loss: 114.2320
#                     Mean surrogate loss: -0.0760
#                       Mean entropy loss: 503.2972
#                             Mean reward: 70.89
#                     Mean episode length: 45.56
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1875
#                 Episode_Reward/tracking: 6.9331
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.71s
#                            Time elapsed: 0:01:16
#                                     ETA: 0:30:32
#
# ################################################################################
#                            Learning iteration 20/500
#
#                             Total steps: 21504
#                        Steps per second: 269
#                         Collection time: 3.622s
#                           Learning time: 0.181s
#                         Mean value loss: 107.8675
#                     Mean surrogate loss: -0.0777
#                       Mean entropy loss: 503.3402
#                             Mean reward: 70.47
#                     Mean episode length: 45.20
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2857
#                 Episode_Reward/tracking: 6.8579
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.80s
#                            Time elapsed: 0:01:20
#                                     ETA: 0:30:28
#
# ################################################################################
#                            Learning iteration 21/500
#
#                             Total steps: 22528
#                        Steps per second: 283
#                         Collection time: 3.461s
#                           Learning time: 0.150s
#                         Mean value loss: 114.0038
#                     Mean surrogate loss: -0.0724
#                       Mean entropy loss: 503.3794
#                             Mean reward: 70.23
#                     Mean episode length: 43.98
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1111
#                 Episode_Reward/tracking: 6.6536
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.61s
#                            Time elapsed: 0:01:23
#                                     ETA: 0:30:19
#
# ################################################################################
#                            Learning iteration 22/500
#
#                             Total steps: 23552
#                        Steps per second: 283
#                         Collection time: 3.453s
#                           Learning time: 0.157s
#                         Mean value loss: 93.6466
#                     Mean surrogate loss: -0.0742
#                       Mean entropy loss: 503.4146
#                             Mean reward: 69.29
#                     Mean episode length: 44.05
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0870
#                 Episode_Reward/tracking: 6.8569
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.61s
#                            Time elapsed: 0:01:27
#                                     ETA: 0:30:11
#
# ################################################################################
#                            Learning iteration 23/500
#
#                             Total steps: 24576
#                        Steps per second: 284
#                         Collection time: 3.453s
#                           Learning time: 0.153s
#                         Mean value loss: 96.2402
#                     Mean surrogate loss: -0.0733
#                       Mean entropy loss: 503.4509
#                             Mean reward: 69.57
#                     Mean episode length: 44.17
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.3333
#                 Episode_Reward/tracking: 6.8190
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.61s
#                            Time elapsed: 0:01:30
#                                     ETA: 0:30:04
#
# ################################################################################
#                            Learning iteration 24/500
#
#                             Total steps: 25600
#                        Steps per second: 307
#                         Collection time: 3.186s
#                           Learning time: 0.139s
#                         Mean value loss: 98.7277
#                     Mean surrogate loss: -0.0754
#                       Mean entropy loss: 503.4851
#                             Mean reward: 68.96
#                     Mean episode length: 43.24
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0500
#                 Episode_Reward/tracking: 6.5807
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.33s
#                            Time elapsed: 0:01:34
#                                     ETA: 0:29:51
#
# ################################################################################
#                            Learning iteration 25/500
#
#                             Total steps: 26624
#                        Steps per second: 289
#                         Collection time: 3.232s
#                           Learning time: 0.307s
#                         Mean value loss: 91.3508
#                     Mean surrogate loss: -0.0800
#                       Mean entropy loss: 503.5274
#                             Mean reward: 70.16
#                     Mean episode length: 43.81
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2500
#                 Episode_Reward/tracking: 7.4205
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.54s
#                            Time elapsed: 0:01:37
#                                     ETA: 0:29:43
#
# ################################################################################
#                            Learning iteration 26/500
#
#                             Total steps: 27648
#                        Steps per second: 301
#                         Collection time: 3.232s
#                           Learning time: 0.165s
#                         Mean value loss: 80.4018
#                     Mean surrogate loss: -0.0727
#                       Mean entropy loss: 503.5737
#                             Mean reward: 71.15
#                     Mean episode length: 44.42
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1333
#                 Episode_Reward/tracking: 7.4335
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.40s
#                            Time elapsed: 0:01:41
#                                     ETA: 0:29:33
#
# ################################################################################
#                            Learning iteration 27/500
#
#                             Total steps: 28672
#                        Steps per second: 335
#                         Collection time: 2.885s
#                           Learning time: 0.167s
#                         Mean value loss: 85.4536
#                     Mean surrogate loss: -0.0772
#                       Mean entropy loss: 503.6187
#                             Mean reward: 72.69
#                     Mean episode length: 46.35
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0870
#                 Episode_Reward/tracking: 7.6175
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.05s
#                            Time elapsed: 0:01:44
#                                     ETA: 0:29:17
#
# ################################################################################
#                            Learning iteration 28/500
#
#                             Total steps: 29696
#                        Steps per second: 318
#                         Collection time: 3.029s
#                           Learning time: 0.189s
#                         Mean value loss: 44.5841
#                     Mean surrogate loss: -0.0750
#                       Mean entropy loss: 503.6633
#                             Mean reward: 73.18
#                     Mean episode length: 46.61
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2353
#                 Episode_Reward/tracking: 6.9186
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.22s
#                            Time elapsed: 0:01:47
#                                     ETA: 0:29:06
#
# ################################################################################
#                            Learning iteration 29/500
#
#                             Total steps: 30720
#                        Steps per second: 308
#                         Collection time: 3.129s
#                           Learning time: 0.192s
#                         Mean value loss: 65.7328
#                     Mean surrogate loss: -0.0792
#                       Mean entropy loss: 503.7091
#                             Mean reward: 72.63
#                     Mean episode length: 47.01
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0000
#                 Episode_Reward/tracking: 6.9473
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.32s
#                            Time elapsed: 0:01:50
#                                     ETA: 0:28:56
#
# ################################################################################
#                            Learning iteration 30/500
#
#                             Total steps: 31744
#                        Steps per second: 283
#                         Collection time: 3.394s
#                           Learning time: 0.213s
#                         Mean value loss: 65.8878
#                     Mean surrogate loss: -0.0744
#                       Mean entropy loss: 503.7564
#                             Mean reward: 73.76
#                     Mean episode length: 49.04
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2941
#                 Episode_Reward/tracking: 8.1192
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.61s
#                            Time elapsed: 0:01:54
#                                     ETA: 0:28:51
#
# ################################################################################
#                            Learning iteration 31/500
#
#                             Total steps: 32768
#                        Steps per second: 260
#                         Collection time: 3.734s
#                           Learning time: 0.192s
#                         Mean value loss: 46.6176
#                     Mean surrogate loss: -0.0749
#                       Mean entropy loss: 503.8028
#                             Mean reward: 72.18
#                     Mean episode length: 48.39
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2500
#                 Episode_Reward/tracking: 6.9399
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.93s
#                            Time elapsed: 0:01:58
#                                     ETA: 0:28:51
#
# ################################################################################
#                            Learning iteration 32/500
#
#                             Total steps: 33792
#                        Steps per second: 269
#                         Collection time: 3.608s
#                           Learning time: 0.197s
#                         Mean value loss: 36.8831
#                     Mean surrogate loss: -0.0773
#                       Mean entropy loss: 503.8544
#                             Mean reward: 71.24
#                     Mean episode length: 48.07
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.3684
#                 Episode_Reward/tracking: 6.9847
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.80s
#                            Time elapsed: 0:02:02
#                                     ETA: 0:28:48
#
# ################################################################################
#                            Learning iteration 33/500
#
#                             Total steps: 34816
#                        Steps per second: 274
#                         Collection time: 3.578s
#                           Learning time: 0.151s
#                         Mean value loss: 41.0697
#                     Mean surrogate loss: -0.0724
#                       Mean entropy loss: 503.9014
#                             Mean reward: 72.01
#                     Mean episode length: 48.27
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.2000
#                 Episode_Reward/tracking: 7.3264
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.73s
#                            Time elapsed: 0:02:05
#                                     ETA: 0:28:45
#
# ################################################################################
#                            Learning iteration 34/500
#
#                             Total steps: 35840
#                        Steps per second: 299
#                         Collection time: 3.281s
#                           Learning time: 0.134s
#                         Mean value loss: 37.9448
#                     Mean surrogate loss: -0.0658
#                       Mean entropy loss: 503.9430
#                             Mean reward: 69.66
#                     Mean episode length: 46.38
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1818
#                 Episode_Reward/tracking: 6.4407
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.41s
#                            Time elapsed: 0:02:09
#                                     ETA: 0:28:37
#
# ################################################################################
#                            Learning iteration 35/500
#
#                             Total steps: 36864
#                        Steps per second: 300
#                         Collection time: 3.264s
#                           Learning time: 0.140s
#                         Mean value loss: 38.7819
#                     Mean surrogate loss: -0.0788
#                       Mean entropy loss: 503.9849
#                             Mean reward: 69.54
#                     Mean episode length: 46.17
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.0952
#                 Episode_Reward/tracking: 7.2376
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.40s
#                            Time elapsed: 0:02:12
#                                     ETA: 0:28:30
#
# ################################################################################
#                            Learning iteration 36/500
#
#                             Total steps: 37888
#                        Steps per second: 308
#                         Collection time: 3.190s
#                           Learning time: 0.132s
#                         Mean value loss: 42.1996
#                     Mean surrogate loss: -0.0746
#                       Mean entropy loss: 504.0312
#                             Mean reward: 69.67
#                     Mean episode length: 45.23
#                         Mean action std: 1.00
#     Episode_Termination/mimic_deviation: 1.1176
#                 Episode_Reward/tracking: 7.1726
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.32s
#                            Time elapsed: 0:02:16
#                                     ETA: 0:28:22
#
# ################################################################################
#                            Learning iteration 37/500
#
#                             Total steps: 38912
#                        Steps per second: 301
#                         Collection time: 3.236s
#                           Learning time: 0.158s
#                         Mean value loss: 39.2276
#                     Mean surrogate loss: -0.0746
#                       Mean entropy loss: 504.0762
#                             Mean reward: 70.21
#                     Mean episode length: 46.22
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1500
#                 Episode_Reward/tracking: 6.8450
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.39s
#                            Time elapsed: 0:02:19
#                                     ETA: 0:28:15
#
# ################################################################################
#                            Learning iteration 38/500
#
#                             Total steps: 39936
#                        Steps per second: 301
#                         Collection time: 3.252s
#                           Learning time: 0.140s
#                         Mean value loss: 34.6783
#                     Mean surrogate loss: -0.0695
#                       Mean entropy loss: 504.1228
#                             Mean reward: 70.47
#                     Mean episode length: 44.51
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.3333
#                 Episode_Reward/tracking: 7.6040
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.39s
#                            Time elapsed: 0:02:22
#                                     ETA: 0:28:08
#
# ################################################################################
#                            Learning iteration 39/500
#
#                             Total steps: 40960
#                        Steps per second: 304
#                         Collection time: 3.224s
#                           Learning time: 0.140s
#                         Mean value loss: 22.7122
#                     Mean surrogate loss: -0.0790
#                       Mean entropy loss: 504.1719
#                             Mean reward: 71.52
#                     Mean episode length: 45.76
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0909
#                 Episode_Reward/tracking: 6.8531
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.36s
#                            Time elapsed: 0:02:26
#                                     ETA: 0:28:01
#
# ################################################################################
#                            Learning iteration 40/500
#
#                             Total steps: 41984
#                        Steps per second: 310
#                         Collection time: 3.155s
#                           Learning time: 0.138s
#                         Mean value loss: 20.9014
#                     Mean surrogate loss: -0.0762
#                       Mean entropy loss: 504.2273
#                             Mean reward: 71.09
#                     Mean episode length: 45.76
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1111
#                 Episode_Reward/tracking: 7.1148
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.29s
#                            Time elapsed: 0:02:29
#                                     ETA: 0:27:53
#
# ################################################################################
#                            Learning iteration 41/500
#
#                             Total steps: 43008
#                        Steps per second: 306
#                         Collection time: 3.209s
#                           Learning time: 0.130s
#                         Mean value loss: 30.7061
#                     Mean surrogate loss: -0.0744
#                       Mean entropy loss: 504.2914
#                             Mean reward: 71.58
#                     Mean episode length: 46.04
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0526
#                 Episode_Reward/tracking: 7.4054
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.34s
#                            Time elapsed: 0:02:32
#                                     ETA: 0:27:46
#
# ################################################################################
#                            Learning iteration 42/500
#
#                             Total steps: 44032
#                        Steps per second: 326
#                         Collection time: 3.004s
#                           Learning time: 0.131s
#                         Mean value loss: 19.5921
#                     Mean surrogate loss: -0.0765
#                       Mean entropy loss: 504.3463
#                             Mean reward: 73.10
#                     Mean episode length: 47.95
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0909
#                 Episode_Reward/tracking: 7.7624
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.14s
#                            Time elapsed: 0:02:35
#                                     ETA: 0:27:37
#
# ################################################################################
#                            Learning iteration 43/500
#
#                             Total steps: 45056
#                        Steps per second: 306
#                         Collection time: 3.201s
#                           Learning time: 0.135s
#                         Mean value loss: 29.6083
#                     Mean surrogate loss: -0.0651
#                       Mean entropy loss: 504.3895
#                             Mean reward: 73.46
#                     Mean episode length: 48.29
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.2222
#                 Episode_Reward/tracking: 7.1278
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.34s
#                            Time elapsed: 0:02:39
#                                     ETA: 0:27:30
#
# ################################################################################
#                            Learning iteration 44/500
#
#                             Total steps: 46080
#                        Steps per second: 290
#                         Collection time: 3.372s
#                           Learning time: 0.151s
#                         Mean value loss: 30.0998
#                     Mean surrogate loss: -0.0711
#                       Mean entropy loss: 504.4229
#                             Mean reward: 73.74
#                     Mean episode length: 47.07
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1765
#                 Episode_Reward/tracking: 7.0473
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.52s
#                            Time elapsed: 0:02:42
#                                     ETA: 0:27:26
#
# ################################################################################
#                            Learning iteration 45/500
#
#                             Total steps: 47104
#                        Steps per second: 363
#                         Collection time: 2.689s
#                           Learning time: 0.125s
#                         Mean value loss: 24.2266
#                     Mean surrogate loss: -0.0690
#                       Mean entropy loss: 504.4547
#                             Mean reward: 74.49
#                     Mean episode length: 47.51
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1579
#                 Episode_Reward/tracking: 7.4439
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 2.81s
#                            Time elapsed: 0:02:45
#                                     ETA: 0:27:14
#
# ################################################################################
# ...
#                         Collection time: 3.273s
#                           Learning time: 0.141s
#                         Mean value loss: 9.8757
#                     Mean surrogate loss: -0.0798
#                       Mean entropy loss: 505.6293
#                             Mean reward: 74.04
#                     Mean episode length: 46.63
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1667
#                 Episode_Reward/tracking: 7.4467
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.41s
#                            Time elapsed: 0:03:59
#                                     ETA: 0:24:28
#
# ################################################################################
#                            Learning iteration 70/500
#
#                             Total steps: 72704
#                        Steps per second: 301
#                         Collection time: 3.251s
#                           Learning time: 0.144s
#                         Mean value loss: 11.6809
#                     Mean surrogate loss: -0.0672
#                       Mean entropy loss: 505.6789
#                             Mean reward: 73.64
#                     Mean episode length: 47.53
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.2500
#                 Episode_Reward/tracking: 7.0560
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.40s
#                            Time elapsed: 0:04:02
#                                     ETA: 0:24:25
#
# ################################################################################
#                            Learning iteration 71/500
#
#                             Total steps: 73728
#                        Steps per second: 303
#                         Collection time: 3.229s
#                           Learning time: 0.141s
#                         Mean value loss: 7.8834
#                     Mean surrogate loss: -0.0768
#                       Mean entropy loss: 505.7351
#                             Mean reward: 73.40
#                     Mean episode length: 48.07
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1176
#                 Episode_Reward/tracking: 7.4222
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.37s
#                            Time elapsed: 0:04:05
#                                     ETA: 0:24:21
#
# ################################################################################
#                            Learning iteration 72/500
#
#                             Total steps: 74752
#                        Steps per second: 297
#                         Collection time: 3.294s
#                           Learning time: 0.148s
#                         Mean value loss: 15.2866
#                     Mean surrogate loss: -0.0674
#                       Mean entropy loss: 505.7976
#                             Mean reward: 73.68
#                     Mean episode length: 47.72
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1053
#                 Episode_Reward/tracking: 7.4073
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.44s
#                            Time elapsed: 0:04:09
#                                     ETA: 0:24:18
#
# ################################################################################
#                            Learning iteration 73/500
#
#                             Total steps: 75776
#                        Steps per second: 298
#                         Collection time: 3.287s
#                           Learning time: 0.148s
#                         Mean value loss: 16.5353
#                     Mean surrogate loss: -0.0580
#                       Mean entropy loss: 505.8554
#                             Mean reward: 72.86
#                     Mean episode length: 47.89
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1579
#                 Episode_Reward/tracking: 7.6558
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.44s
#                            Time elapsed: 0:04:12
#                                     ETA: 0:24:15
#
# ################################################################################
#                            Learning iteration 74/500
#
#                             Total steps: 76800
#                        Steps per second: 299
#                         Collection time: 3.280s
#                           Learning time: 0.139s
#                         Mean value loss: 11.3640
#                     Mean surrogate loss: -0.0728
#                       Mean entropy loss: 505.9140
#                             Mean reward: 74.11
#                     Mean episode length: 48.31
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0500
#                 Episode_Reward/tracking: 7.3481
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.42s
#                            Time elapsed: 0:04:16
#                                     ETA: 0:24:11
#
# ################################################################################
#                            Learning iteration 75/500
#
#                             Total steps: 77824
#                        Steps per second: 302
#                         Collection time: 3.237s
#                           Learning time: 0.154s
#                         Mean value loss: 12.1091
#                     Mean surrogate loss: -0.0613
#                       Mean entropy loss: 505.9671
#                             Mean reward: 73.66
#                     Mean episode length: 48.39
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.3571
#                 Episode_Reward/tracking: 7.2895
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.39s
#                            Time elapsed: 0:04:19
#                                     ETA: 0:24:08
#
# ################################################################################
#                            Learning iteration 76/500
#
#                             Total steps: 78848
#                        Steps per second: 298
#                         Collection time: 3.272s
#                           Learning time: 0.158s
#                         Mean value loss: 13.2824
#                     Mean surrogate loss: -0.0735
#                       Mean entropy loss: 506.0181
#                             Mean reward: 73.98
#                     Mean episode length: 48.41
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1053
#                 Episode_Reward/tracking: 7.2739
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.43s
#                            Time elapsed: 0:04:23
#                                     ETA: 0:24:04
#
# ################################################################################
#                            Learning iteration 77/500
#
#                             Total steps: 79872
#                        Steps per second: 297
#                         Collection time: 3.294s
#                           Learning time: 0.144s
#                         Mean value loss: 6.8341
#                     Mean surrogate loss: -0.0732
#                       Mean entropy loss: 506.0710
#                             Mean reward: 73.27
#                     Mean episode length: 48.99
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1053
#                 Episode_Reward/tracking: 7.3758
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.44s
#                            Time elapsed: 0:04:26
#                                     ETA: 0:24:01
#
# ################################################################################
#                            Learning iteration 78/500
#
#                             Total steps: 80896
#                        Steps per second: 295
#                         Collection time: 3.322s
#                           Learning time: 0.139s
#                         Mean value loss: 10.3062
#                     Mean surrogate loss: -0.0619
#                       Mean entropy loss: 506.1272
#                             Mean reward: 72.58
#                     Mean episode length: 47.79
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1364
#                 Episode_Reward/tracking: 7.0746
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.46s
#                            Time elapsed: 0:04:29
#                                     ETA: 0:23:58
#
# ################################################################################
#                            Learning iteration 79/500
#
#                             Total steps: 81920
#                        Steps per second: 300
#                         Collection time: 3.270s
#                           Learning time: 0.140s
#                         Mean value loss: 8.2174
#                     Mean surrogate loss: -0.0696
#                       Mean entropy loss: 506.1861
#                             Mean reward: 73.28
#                     Mean episode length: 48.42
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0476
#                 Episode_Reward/tracking: 7.4042
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.41s
#                            Time elapsed: 0:04:33
#                                     ETA: 0:23:54
#
# ################################################################################
#                            Learning iteration 80/500
#
#                             Total steps: 82944
#                        Steps per second: 298
#                         Collection time: 3.293s
#                           Learning time: 0.139s
#                         Mean value loss: 6.6299
#                     Mean surrogate loss: -0.0707
#                       Mean entropy loss: 506.2401
#                             Mean reward: 73.01
#                     Mean episode length: 47.20
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0500
#                 Episode_Reward/tracking: 7.3604
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.43s
#                            Time elapsed: 0:04:36
#                                     ETA: 0:23:51
#
# ################################################################################
#                            Learning iteration 81/500
#
#                             Total steps: 83968
#                        Steps per second: 298
#                         Collection time: 3.296s
#                           Learning time: 0.138s
#                         Mean value loss: 11.5882
#                     Mean surrogate loss: -0.0626
#                       Mean entropy loss: 506.2877
#                             Mean reward: 70.99
#                     Mean episode length: 45.53
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0833
#                 Episode_Reward/tracking: 6.7037
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.43s
#                            Time elapsed: 0:04:40
#                                     ETA: 0:23:48
#
# ################################################################################
#                            Learning iteration 82/500
#
#                             Total steps: 84992
#                        Steps per second: 301
#                         Collection time: 3.257s
#                           Learning time: 0.138s
#                         Mean value loss: 16.5547
#                     Mean surrogate loss: -0.0660
#                       Mean entropy loss: 506.3377
#                             Mean reward: 70.12
#                     Mean episode length: 44.77
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.1500
#                 Episode_Reward/tracking: 6.4705
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.39s
#                            Time elapsed: 0:04:43
#                                     ETA: 0:23:44
#
# ################################################################################
#                            Learning iteration 83/500
#
#                             Total steps: 86016
#                        Steps per second: 299
#                         Collection time: 3.271s
#                           Learning time: 0.149s
#                         Mean value loss: 10.5647
#                     Mean surrogate loss: -0.0596
#                       Mean entropy loss: 506.3940
#                             Mean reward: 69.98
#                     Mean episode length: 45.02
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0588
#                 Episode_Reward/tracking: 7.1149
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.42s
#                            Time elapsed: 0:04:46
#                                     ETA: 0:23:41
#
# ################################################################################
#                            Learning iteration 84/500
#
#                             Total steps: 87040
#                        Steps per second: 298
#                         Collection time: 3.286s
#                           Learning time: 0.145s
#                         Mean value loss: 7.3585
#                     Mean surrogate loss: -0.0709
#                       Mean entropy loss: 506.4484
#                             Mean reward: 70.15
#                     Mean episode length: 46.13
#                         Mean action std: 1.01
#     Episode_Termination/mimic_deviation: 1.0952
#                 Episode_Reward/tracking: 7.3533
#            Episode_Termination/time_out: 0.0000
# --------------------------------------------------------------------------------
#                          Iteration time: 3.43s
#                            Time elapsed: 0:04:50
#                                     ETA: 0:23:37

# %% [markdown]
# ## 6. Render trained policy as inline video
#
# Loads the latest checkpoint from the training log directory, runs it in a
# single-env `ManagerBasedRlEnv` with `render_mode="rgb_array"`, and writes
# an MP4.  Falls back to a zero-action rollout if no checkpoint is found.

# %%
if _MJLAB_OK and _MJLAB_RUN and CLIP_PATH:
    import glob, torch, mediapy
    from pathlib import Path
    from IPython.display import Video, display
    from mjlab.envs import ManagerBasedRlEnv
    from mjlab.viewer import ViewerConfig

    from mjlab.tasks.registry import list_tasks, load_env_cfg, register_mjlab_task
    from myosuite.envs.myo.backends.mjlab.mimic_mjlab_env import (
        default_mimic_clip_on_policy_runner_cfg,
        register_mimic_mjlab_tasks_with_clip,
    )

    N_FRAMES   = int(os.environ.get('MJLAB_MIMIC_RENDER_FRAMES', '300'))
    FPS        = 30
    VIDEO_PATH = '/tmp/mjlab_policy_rollout.mp4'

    # ── load latest checkpoint (sort by iteration — glob order is lexical) ─
    import re

    def _ckpt_iter(path: str) -> int:
        m = re.search(r'model_(\d+)\.pt$', path.replace('\\', '/'))
        return int(m.group(1)) if m else -1

    ckpts = sorted(
        glob.glob(f'{TRAIN_LOG_DIR}/**/model_*.pt', recursive=True),
        key=_ckpt_iter,
    )
    policy_fn = None
    if ckpts:
        latest = ckpts[-1]
        print(f'Loading checkpoint: {latest}')
        # rsl_rl EmpiricalNormalization buffers can be inference tensors after
        # training; load_state_dict must run under inference_mode (PyTorch 2.x).
        with torch.inference_mode():
            runner.load(latest, map_location=_DEVICE)
        policy_fn = runner.get_inference_policy(device=_DEVICE)
    else:
        print('No checkpoint found — rendering zero-action rollout.')

    # ── render env ────────────────────────────────────────────────────────
    if 'myoMimicFullbody-v0' not in list_tasks():
        from myosuite.core.trajectory_io import load_motion_clip
        _clip = load_motion_clip(CLIP_PATH, expected_nq=89, expected_nv=88)
        register_mimic_mjlab_tasks_with_clip(
            register_mjlab_task=register_mjlab_task,
            rl_cfg_fn=default_mimic_clip_on_policy_runner_cfg,
            clip=_clip,
            use_lookahead=True,
        )
    render_cfg = load_env_cfg('myoMimicFullbody-v0', play=True)
    render_cfg.scene.num_envs = 1
    render_cfg.viewer = ViewerConfig(width=640, height=360, distance=3.5, elevation=-20.0)

    render_env = ManagerBasedRlEnv(cfg=render_cfg, device=_DEVICE, render_mode='rgb_array')
    obs, _ = render_env.reset()
    act_dim_r = render_env.action_space.shape[-1]

    frames = []
    for _ in range(N_FRAMES):
        if policy_fn is not None:
            with torch.no_grad():
                # rsl_rl MLPModel expects a TensorDict with keys from obs_groups (e.g. 'actor').
                actions = policy_fn(obs)
        else:
            actions = torch.zeros(1, act_dim_r, device=_DEVICE)
        obs, _, _, _, _ = render_env.step(actions)
        frame = render_env.render()
        if frame is not None:
            frames.append(frame)

    render_env.close()
    if not frames:
        raise RuntimeError('No frames captured; check render_mode and viewer config.')
    print(f'Captured {len(frames)} frames  ({frames[0].shape} each)')

    mediapy.write_video(VIDEO_PATH, frames, fps=FPS)
    display(Video(VIDEO_PATH, embed=True, width=640, height=360))

# %% [markdown]
# ## 7. Architecture summary
#
# ```
# motion clip (.npz)
#   └── load_motion_clip()  →  MotionClip
#         └── register_mimic_mjlab_tasks_with_clip()
#               └── ManagerBasedRlEnvCfg
#                     ├── SceneCfg  (EntityCfg → MjSpec → mujoco_warp / Warp)
#                     ├── ObservationManager  (groups: policy / actor / critic)
#                     ├── ActionManager  (MyoMuscleActivationAction)
#                     ├── RewardManager  (DeepMimic composite)
#                     └── TerminationManager  (time_out + mimic_deviation)
#
# ManagerBasedRlEnv
#   └── RslRlVecEnvWrapper
#         └── MjlabOnPolicyRunner  →  PPO (rsl_rl)
# ```
#
# **Key files**
#
# | File | Role |
# |------|------|
# | `myosuite/envs/myo/backends/mjlab/mimic_mjlab_env.py` | Task wiring, obs/reward/termination closures, init state |
# | `myosuite/envs/myo/backends/mjlab/register_mjlab_tasks.py` | `MyoMuscleActivationAction`, actuator helpers |
# | `myosuite/core/trajectory_io.py` | `load_motion_clip`, `MotionClip` dataclass |
# | `myosuite/envs/myo/backends/mjlab/clip_trajectory_source.py` | Per-env frame sampling from clip |
